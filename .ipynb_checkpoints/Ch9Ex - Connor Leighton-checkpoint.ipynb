# %% [markdown]
# # Chapter 9 Exercises

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Question 2: Capital Quiz
#
# Write a program that creates a dictionary containing the U.S. states as keys, and their capitals as values. (Use the Internet to get a list of the states and their capitals.) The program should then randomly quiz the user by displaying the name of a state and asking the user to enter that state’s capital. The program should keep a count of the number of correct and incorrect responses. (As an alternative to the U.S. states, the program can use the names of countries and their capitals.)

# %%
def create_state_capital_dictionary():
    state_capital_dictionary = {
        'Alabama': 'Montgomery', 
        'Alaska': 'Juneau', 
        'Arizona': 'Phoenix',
        'Arkansas': 'Little Rock',
        'California': 'Sacremento',
        'Colorado': 'Denver',
        'Connecticut': 'Hartford',
        'Delaware': 'Dover',
        'Florida': 'Tallahassee',
        'Georgia': 'Atlanta',
        'Hawaii': 'Honolulu',
        'Idaho': 'Boise',
        'illinois': 'Springfield',
        'Indiana': 'Indianapolis',
        'Iowa': 'Des Moines',
        'Kansas': 'Topeka',
        'Kentucky': 'Frankfort',
        'Louisiana': 'Baton Rouge',
        'Maine': 'Augusta',
        'Maryland': 'Annapolis',
        'Massachusettes': 'Boston',
        'Michigan': 'Lansing',
        'Minnesota': 'Saint Paul',
        'Mississippi': 'Jackson',
        'Missouri': 'Jefferson City',
        'Montana': 'Helena',
        'Nebraska': 'Lincoln',
        'Nevada': 'Carson City',
        'New Hampshire': 'Concord',
        'New Jersey': 'Trenton',
        'New Mexico': 'Santa Fe',
        'New York': 'Albany',
        'North Carolina': 'Raleigh',
        'North Dakota': 'Bismark',
        'Ohio': 'Columbus',
        'Oklahoma': 'Oklahoma City',
        'Oregon': 'Salem',
        'Pennsylvania': 'Harrisburg',
        'Rhode Island': 'Providence',
        'South Carolina': 'Columbia',
        'South Dakota': 'Pierre',
        'Tennessee': 'Nashville',
        'Texas': 'Austin',
        'Utah': 'Salt Lake City',
        'Vermont': 'Montpelier',
        'Virginia': 'Richmond',
        'Washington': 'Olympia',
        'West Virginia':'Charleston',
        'Wisconson': 'Madison',
        'Wyoming': 'Cheyenne'
    }
    return state_capital_dictionary

# %% [markdown]
# I created the dictionary for all the states and their capitals.

# %%
def create_state_capital_dictionary():
    state_capital_dictionary = {
        'Alabama': 'Montgomery', 
        'Alaska': 'Juneau', 
        'Arizona': 'Phoenix',
        'Arkansas': 'Little Rock',
        'California': 'Sacremento',
        'Colorado': 'Denver',
        'Connecticut': 'Hartford',
        'Delaware': 'Dover',
        'Florida': 'Tallahassee',
        'Georgia': 'Atlanta',
        'Hawaii': 'Honolulu',
        'Idaho': 'Boise',
        'illinois': 'Springfield',
        'Indiana': 'Indianapolis',
        'Iowa': 'Des Moines',
        'Kansas': 'Topeka',
        'Kentucky': 'Frankfort',
        'Louisiana': 'Baton Rouge',
        'Maine': 'Augusta',
        'Maryland': 'Annapolis',
        'Massachusettes': 'Boston',
        'Michigan': 'Lansing',
        'Minnesota': 'Saint Paul',
        'Mississippi': 'Jackson',
        'Missouri': 'Jefferson City',
        'Montana': 'Helena',
        'Nebraska': 'Lincoln',
        'Nevada': 'Carson City',
        'New Hampshire': 'Concord',
        'New Jersey': 'Trenton',
        'New Mexico': 'Santa Fe',
        'New York': 'Albany',
        'North Carolina': 'Raleigh',
        'North Dakota': 'Bismark',
        'Ohio': 'Columbus',
        'Oklahoma': 'Oklahoma City',
        'Oregon': 'Salem',
        'Pennsylvania': 'Harrisburg',
        'Rhode Island': 'Providence',
        'South Carolina': 'Columbia',
        'South Dakota': 'Pierre',
        'Tennessee': 'Nashville',
        'Texas': 'Austin',
        'Utah': 'Salt Lake City',
        'Vermont': 'Montpelier',
        'Virginia': 'Richmond',
        'Washington': 'Olympia',
        'West Virginia':'Charleston',
        'Wisconson': 'Madison',
        'Wyoming': 'Cheyenne'
    }
    return state_capital_dictionary

#initializing correct and incorrect answers
def quiz_user(state_capital_dictionary):
    correct_answers = 0
    incorrect_answers = 0

# %% [markdown]
# I started by defining the function quiz_user and setting the correct/incorrect variables to zero.

# %%
def create_state_capital_dictionary():
    state_capital_dictionary = {
        'Alabama': 'Montgomery', 
        'Alaska': 'Juneau', 
        'Arizona': 'Phoenix',
        'Arkansas': 'Little Rock',
        'California': 'Sacremento',
        'Colorado': 'Denver',
        'Connecticut': 'Hartford',
        'Delaware': 'Dover',
        'Florida': 'Tallahassee',
        'Georgia': 'Atlanta',
        'Hawaii': 'Honolulu',
        'Idaho': 'Boise',
        'illinois': 'Springfield',
        'Indiana': 'Indianapolis',
        'Iowa': 'Des Moines',
        'Kansas': 'Topeka',
        'Kentucky': 'Frankfort',
        'Louisiana': 'Baton Rouge',
        'Maine': 'Augusta',
        'Maryland': 'Annapolis',
        'Massachusettes': 'Boston',
        'Michigan': 'Lansing',
        'Minnesota': 'Saint Paul',
        'Mississippi': 'Jackson',
        'Missouri': 'Jefferson City',
        'Montana': 'Helena',
        'Nebraska': 'Lincoln',
        'Nevada': 'Carson City',
        'New Hampshire': 'Concord',
        'New Jersey': 'Trenton',
        'New Mexico': 'Santa Fe',
        'New York': 'Albany',
        'North Carolina': 'Raleigh',
        'North Dakota': 'Bismark',
        'Ohio': 'Columbus',
        'Oklahoma': 'Oklahoma City',
        'Oregon': 'Salem',
        'Pennsylvania': 'Harrisburg',
        'Rhode Island': 'Providence',
        'South Carolina': 'Columbia',
        'South Dakota': 'Pierre',
        'Tennessee': 'Nashville',
        'Texas': 'Austin',
        'Utah': 'Salt Lake City',
        'Vermont': 'Montpelier',
        'Virginia': 'Richmond',
        'Washington': 'Olympia',
        'West Virginia':'Charleston',
        'Wisconson': 'Madison',
        'Wyoming': 'Cheyenne'
    }
    return state_capital_dictionary

#initializing correct and incorrect answers
def quiz_user(state_capital_dictionary):
    correct_answers = 0
    incorrect_answers = 0
   
    #Quiz the user
    for state in state_capital_dictionary:
        capital = state_capital_dictionary[state]
        user_guess = input(f'what is the capital of {state}')

# %% [markdown]
# I made a for loop where capital is state_capital_dictionary[state]. I then added another variable called user_guess which is the input of what the user guesses the capital to be.

# %%
import random

def create_state_capital_dictionary():
    state_capital_dictionary = {
        'Alabama': 'Montgomery', 
        'Alaska': 'Juneau', 
        'Arizona': 'Phoenix',
        'Arkansas': 'Little Rock',
        'California': 'Sacremento',
        'Colorado': 'Denver',
        'Connecticut': 'Hartford',
        'Delaware': 'Dover',
        'Florida': 'Tallahassee',
        'Georgia': 'Atlanta',
        'Hawaii': 'Honolulu',
        'Idaho': 'Boise',
        'illinois': 'Springfield',
        'Indiana': 'Indianapolis',
        'Iowa': 'Des Moines',
        'Kansas': 'Topeka',
        'Kentucky': 'Frankfort',
        'Louisiana': 'Baton Rouge',
        'Maine': 'Augusta',
        'Maryland': 'Annapolis',
        'Massachusettes': 'Boston',
        'Michigan': 'Lansing',
        'Minnesota': 'Saint Paul',
        'Mississippi': 'Jackson',
        'Missouri': 'Jefferson City',
        'Montana': 'Helena',
        'Nebraska': 'Lincoln',
        'Nevada': 'Carson City',
        'New Hampshire': 'Concord',
        'New Jersey': 'Trenton',
        'New Mexico': 'Santa Fe',
        'New York': 'Albany',
        'North Carolina': 'Raleigh',
        'North Dakota': 'Bismark',
        'Ohio': 'Columbus',
        'Oklahoma': 'Oklahoma City',
        'Oregon': 'Salem',
        'Pennsylvania': 'Harrisburg',
        'Rhode Island': 'Providence',
        'South Carolina': 'Columbia',
        'South Dakota': 'Pierre',
        'Tennessee': 'Nashville',
        'Texas': 'Austin',
        'Utah': 'Salt Lake City',
        'Vermont': 'Montpelier',
        'Virginia': 'Richmond',
        'Washington': 'Olympia',
        'West Virginia':'Charleston',
        'Wisconson': 'Madison',
        'Wyoming': 'Cheyenne'
    }
    return state_capital_dictionary

#initializing correct and incorrect answers
def quiz_user(state_capital_dictionary):
    correct_answers = 0
    incorrect_answers = 0
   
    #Quiz the user
    for state in state_capital_dictionary:
        capital = state_capital_dictionary[state]
        user_guess = input(f'what is the capital of {state}')
        
        if user_guess == capital:
            print('correct')
            correct_answers += 1
            
        else:
            print('incorrect')
            incorrect_answers += 1

# %% [markdown]
# I added an if else statement where if the user gets a correct answer, the correct answer variable gets one point added, and vise versa

# %%
import random

def create_state_capital_dictionary():
    state_capital_dictionary = {
        'Alabama': 'Montgomery', 
        'Alaska': 'Juneau', 
        'Arizona': 'Phoenix',
        'Arkansas': 'Little Rock',
        'California': 'Sacremento',
        'Colorado': 'Denver',
        'Connecticut': 'Hartford',
        'Delaware': 'Dover',
        'Florida': 'Tallahassee',
        'Georgia': 'Atlanta',
        'Hawaii': 'Honolulu',
        'Idaho': 'Boise',
        'illinois': 'Springfield',
        'Indiana': 'Indianapolis',
        'Iowa': 'Des Moines',
        'Kansas': 'Topeka',
        'Kentucky': 'Frankfort',
        'Louisiana': 'Baton Rouge',
        'Maine': 'Augusta',
        'Maryland': 'Annapolis',
        'Massachusettes': 'Boston',
        'Michigan': 'Lansing',
        'Minnesota': 'Saint Paul',
        'Mississippi': 'Jackson',
        'Missouri': 'Jefferson City',
        'Montana': 'Helena',
        'Nebraska': 'Lincoln',
        'Nevada': 'Carson City',
        'New Hampshire': 'Concord',
        'New Jersey': 'Trenton',
        'New Mexico': 'Santa Fe',
        'New York': 'Albany',
        'North Carolina': 'Raleigh',
        'North Dakota': 'Bismark',
        'Ohio': 'Columbus',
        'Oklahoma': 'Oklahoma City',
        'Oregon': 'Salem',
        'Pennsylvania': 'Harrisburg',
        'Rhode Island': 'Providence',
        'South Carolina': 'Columbia',
        'South Dakota': 'Pierre',
        'Tennessee': 'Nashville',
        'Texas': 'Austin',
        'Utah': 'Salt Lake City',
        'Vermont': 'Montpelier',
        'Virginia': 'Richmond',
        'Washington': 'Olympia',
        'West Virginia':'Charleston',
        'Wisconson': 'Madison',
        'Wyoming': 'Cheyenne'
    }
    return state_capital_dictionary

#initializing correct and incorrect answers
def quiz_user(state_capital_dictionary):
    correct_answers = 0
    incorrect_answers = 0
   
    #Quiz the user
    for state in state_capital_dictionary:
        capital = state_capital_dictionary[state]
        user_guess = input(f'What is the capital of {state}')
        
        if user_guess == capital:
            print('Correct')
            correct_answers += 1
            
        else:
            print('Incorrect')
            incorrect_answers += 1
            
    #display results
    total_questions = len(state_capital_dictionary)
    print('Quiz results:')
    print('Total questions:', total_questions)
    print('Correct answers:', correct_answers)
    print('incorrect answers:', incorrect_answers)

# %% [markdown]
# I added 4 print statements for displaying how many correct and incorrect answers the user got

# %%
import random

def create_state_capital_dictionary():
    state_capital_dictionary = {
        'Alabama': 'Montgomery', 
        'Alaska': 'Juneau', 
        'Arizona': 'Phoenix',
        'Arkansas': 'Little Rock',
        'California': 'Sacremento',
        'Colorado': 'Denver',
        'Connecticut': 'Hartford',
        'Delaware': 'Dover',
        'Florida': 'Tallahassee',
        'Georgia': 'Atlanta',
        'Hawaii': 'Honolulu',
        'Idaho': 'Boise',
        'illinois': 'Springfield',
        'Indiana': 'Indianapolis',
        'Iowa': 'Des Moines',
        'Kansas': 'Topeka',
        'Kentucky': 'Frankfort',
        'Louisiana': 'Baton Rouge',
        'Maine': 'Augusta',
        'Maryland': 'Annapolis',
        'Massachusettes': 'Boston',
        'Michigan': 'Lansing',
        'Minnesota': 'Saint Paul',
        'Mississippi': 'Jackson',
        'Missouri': 'Jefferson City',
        'Montana': 'Helena',
        'Nebraska': 'Lincoln',
        'Nevada': 'Carson City',
        'New Hampshire': 'Concord',
        'New Jersey': 'Trenton',
        'New Mexico': 'Santa Fe',
        'New York': 'Albany',
        'North Carolina': 'Raleigh',
        'North Dakota': 'Bismark',
        'Ohio': 'Columbus',
        'Oklahoma': 'Oklahoma City',
        'Oregon': 'Salem',
        'Pennsylvania': 'Harrisburg',
        'Rhode Island': 'Providence',
        'South Carolina': 'Columbia',
        'South Dakota': 'Pierre',
        'Tennessee': 'Nashville',
        'Texas': 'Austin',
        'Utah': 'Salt Lake City',
        'Vermont': 'Montpelier',
        'Virginia': 'Richmond',
        'Washington': 'Olympia',
        'West Virginia':'Charleston',
        'Wisconson': 'Madison',
        'Wyoming': 'Cheyenne'
    }
    return state_capital_dictionary

#initializing correct and incorrect answers
def quiz_user(state_capital_dictionary):
    correct_answers = 0
    incorrect_answers = 0
   
    #Quiz the user
    for state in state_capital_dictionary:
        capital = state_capital_dictionary[state]
        user_guess = input(f'What is the capital of {state}')
        
        if user_guess == capital:
            print('Correct')
            correct_answers += 1
            
        else:
            print('Incorrect')
            incorrect_answers += 1
            
    #display results
    total_questions = len(state_capital_dictionary)
    print('Quiz results:')
    print('Total questions:', total_questions)
    print('Correct answers:', correct_answers)
    print('incorrect answers:', incorrect_answers)
    
state_capital_dictionary = create_state_capital_dictionary()
quiz_user(state_capital_dictionary)
# Out:
# What is the capital of AlabamaMontgomery
# Correct
# What is the capital of AlaskaJuneau
# Correct
# What is the capital of ArizonaPhoenix
# Correct
# What is the capital of ArkansasLittle Rock
# Correct
# What is the capital of CaliforniaSacremento
# Correct
# What is the capital of ColoradoDenver
# Correct
# What is the capital of ConnecticutHartford
# Correct
# What is the capital of DelawareDover
# Correct
# What is the capital of FloridaTalahassee
# Incorrect
# What is the capital of GeorgiaAtlanta
# Correct
# What is the capital of HawaiiHonolulu
# Correct
# What is the capital of IdahoBoise
# Correct
# What is the capital of illinoisSpringfield
# Correct
# What is the capital of IndianaIndianapolis
# Correct
# What is the capital of IowaDe Moine
# Incorrect
# What is the capital of KansasTopeka
# Correct
# What is the capital of Kentuckyidk
# Incorrect
# What is the capital of LouisianaBaton Rouge
# Correct
# What is the capital of MaineAugusta
# Correct
# ...

# %% [markdown]
# I finally got the code to run. now, I want to make it look better and make it random

# %%
import random

def create_state_capital_dictionary():
    state_capital_dictionary = {
        'Alabama': 'Montgomery', 
        'Alaska': 'Juneau', 
        'Arizona': 'Phoenix',
        'Arkansas': 'Little Rock',
        'California': 'Sacremento',
        'Colorado': 'Denver',
        'Connecticut': 'Hartford',
        'Delaware': 'Dover',
        'Florida': 'Tallahassee',
        'Georgia': 'Atlanta',
        'Hawaii': 'Honolulu',
        'Idaho': 'Boise',
        'illinois': 'Springfield',
        'Indiana': 'Indianapolis',
        'Iowa': 'Des Moines',
        'Kansas': 'Topeka',
        'Kentucky': 'Frankfort',
        'Louisiana': 'Baton Rouge',
        'Maine': 'Augusta',
        'Maryland': 'Annapolis',
        'Massachusettes': 'Boston',
        'Michigan': 'Lansing',
        'Minnesota': 'Saint Paul',
        'Mississippi': 'Jackson',
        'Missouri': 'Jefferson City',
        'Montana': 'Helena',
        'Nebraska': 'Lincoln',
        'Nevada': 'Carson City',
        'New Hampshire': 'Concord',
        'New Jersey': 'Trenton',
        'New Mexico': 'Santa Fe',
        'New York': 'Albany',
        'North Carolina': 'Raleigh',
        'North Dakota': 'Bismark',
        'Ohio': 'Columbus',
        'Oklahoma': 'Oklahoma City',
        'Oregon': 'Salem',
        'Pennsylvania': 'Harrisburg',
        'Rhode Island': 'Providence',
        'South Carolina': 'Columbia',
        'South Dakota': 'Pierre',
        'Tennessee': 'Nashville',
        'Texas': 'Austin',
        'Utah': 'Salt Lake City',
        'Vermont': 'Montpelier',
        'Virginia': 'Richmond',
        'Washington': 'Olympia',
        'West Virginia':'Charleston',
        'Wisconson': 'Madison',
        'Wyoming': 'Cheyenne'
    }
    return state_capital_dictionary

#initializing correct and incorrect answers
def quiz_user(state_capital_dictionary):
    correct_answers = 0
    incorrect_answers = 0
    
    #randomizing the states
    states = list(state_capital_dictionary.keys())
    random.shuffle(states)
   
    #Quiz the user
    for state in state_capital_dictionary:
        capital = state_capital_dictionary[state]
        user_guess = input(f'What is the capital of {state}: ')
        
        if user_guess == capital:
            print('Correct')
            correct_answers += 1
            
        else:
            print('Incorrect, the correct answer is {capital}')
            incorrect_answers += 1
            
    #display results
    total_questions = len(state_capital_dictionary)
    print('\nQuiz results:')
    print('-------------------------')
    print('Total questions:', total_questions)
    print('Correct answers:', correct_answers)
    print('incorrect answers:', incorrect_answers)
    
state_capital_dictionary = create_state_capital_dictionary()
quiz_user(state_capital_dictionary)
# Out:
# What is the capital of Alabama: montgomery
# Incorrect, the correct answer is {capital}
# What is the capital of Alaska: Juneau
# Correct
# What is the capital of Arizona: Phoenix
# Correct
# What is the capital of Arkansas: a
# Incorrect, the correct answer is {capital}
# What is the capital of California: a
# Incorrect, the correct answer is {capital}
# What is the capital of Colorado: a
# Incorrect, the correct answer is {capital}
# What is the capital of Connecticut: a
# Incorrect, the correct answer is {capital}
# What is the capital of Delaware: a
# Incorrect, the correct answer is {capital}
# What is the capital of Florida: a
# Incorrect, the correct answer is {capital}
# What is the capital of Georgia: a
# Incorrect, the correct answer is {capital}
# What is the capital of Hawaii: a
# Incorrect, the correct answer is {capital}
# What is the capital of Idaho: a
# Incorrect, the correct answer is {capital}
# What is the capital of illinois: a
# ...

# %% [markdown]
# Using the help of ChatGPT, I tried to randomize the states, but that did not work.

# %%
import random

def create_state_capital_dictionary():
    state_capital_dictionary = {
        'Alabama': 'Montgomery', 
        'Alaska': 'Juneau', 
        'Arizona': 'Phoenix',
        'Arkansas': 'Little Rock',
        'California': 'Sacramento',
        'Colorado': 'Denver',
        'Connecticut': 'Hartford',
        'Delaware': 'Dover',
        'Florida': 'Tallahassee',
        'Georgia': 'Atlanta',
        'Hawaii': 'Honolulu',
        'Idaho': 'Boise',
        'Illinois': 'Springfield',
        'Indiana': 'Indianapolis',
        'Iowa': 'Des Moines',
        'Kansas': 'Topeka',
        'Kentucky': 'Frankfort',
        'Louisiana': 'Baton Rouge',
        'Maine': 'Augusta',
        'Maryland': 'Annapolis',
        'Massachusetts': 'Boston',
        'Michigan': 'Lansing',
        'Minnesota': 'Saint Paul',
        'Mississippi': 'Jackson',
        'Missouri': 'Jefferson City',
        'Montana': 'Helena',
        'Nebraska': 'Lincoln',
        'Nevada': 'Carson City',
        'New Hampshire': 'Concord',
        'New Jersey': 'Trenton',
        'New Mexico': 'Santa Fe',
        'New York': 'Albany',
        'North Carolina': 'Raleigh',
        'North Dakota': 'Bismarck',
        'Ohio': 'Columbus',
        'Oklahoma': 'Oklahoma City',
        'Oregon': 'Salem',
        'Pennsylvania': 'Harrisburg',
        'Rhode Island': 'Providence',
        'South Carolina': 'Columbia',
        'South Dakota': 'Pierre',
        'Tennessee': 'Nashville',
        'Texas': 'Austin',
        'Utah': 'Salt Lake City',
        'Vermont': 'Montpelier',
        'Virginia': 'Richmond',
        'Washington': 'Olympia',
        'West Virginia':'Charleston',
        'Wisconsin': 'Madison',
        'Wyoming': 'Cheyenne'
    }
    return state_capital_dictionary

#Quiz the user
def quiz_user(state_capital_dictionary):
    correct_answers = 0
    incorrect_answers = 0
    
    #Shuffle the order of states
    states = list(state_capital_dictionary.keys())
    random.shuffle(states)
    
    #Quiz the user
    for state in states:
        capital = state_capital_dictionary[state]
        user_guess = input(f'What is the capital of {state}: ')
        
        if user_guess == capital:
            print('Correct')
            correct_answers += 1
        else:
            print(f'Incorrect, the correct answer is {capital}')
            incorrect_answers += 1
    
    #Display results
    total_questions = len(state_capital_dictionary)
    print('\nQuiz results:')
    print('-------------------------')
    print('Total questions:', total_questions)
    print('Correct answers:', correct_answers)
    print('Incorrect answers:', incorrect_answers)

state_capital_dictionary = create_state_capital_dictionary()
quiz_user(state_capital_dictionary)
# Out:
# What is the capital of New Mexico: Santa Fe
# Correct
# What is the capital of Arizona: Phoenix
# Correct
# What is the capital of Indiana: Indianapolis
# Correct
# What is the capital of South Dakota: idk
# Incorrect, the correct answer is Pierre
# What is the capital of Pennsylvania: Harrisburg
# Correct
# What is the capital of Rhode Island: Providence
# Correct
# What is the capital of North Carolina: Raleigh
# Correct
# What is the capital of Oklahoma: Oklahoma City
# Correct
# What is the capital of Kentucky: idk
# Incorrect, the correct answer is Frankfort
# What is the capital of California: Sacramento
# Incorrect, the correct answer is Sacremento
# What is the capital of Montana: Helena
# Correct
# What is the capital of Louisiana: Baton Rouge
# Correct
# What is the capital of North Dakota: Bismark
# Correct
# What is the capital of Florida: Tallahassee
# Correct
# What is the capital of Tennessee: Nashville
# Correct
# What is the capital of Iowa: Des Moine
# ...

# %% [markdown]
# After testing the same code once more, It finally randomized.
