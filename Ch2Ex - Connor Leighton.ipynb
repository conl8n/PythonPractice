# %% [markdown]
# # Chapter 2 Exercises

# %% [markdown]
# ## Algorithm Workbench

# %% [markdown]
# ### Problem 15
#
# The textbook asks us to Write the turtle graphics statements to draw a square that is 100 pixels wide on each side and a circle that is centered inside the square. The circle’s radius should be 80 pixels. The circle should be filled with the color red. (The square should not be filled with a color.)

# %%
#To use the turtle graphics system, I need to import the turtle module
import turtue
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 #To use the turtle graphics system, I need to import the turtle module
# ----> 2 import turtue
#
# ModuleNotFoundError: No module named 'turtue'

# %%
#spelling error
import turtle

# %%
#moving the turtle forward 100 pixels
turtle.forward(100)

# %% [markdown]
# ![Python%20Turtle%20Graphics%201_20_2024%209_51_56%20PM.png](attachment:Python%20Turtle%20Graphics%201_20_2024%209_51_56%20PM.png)

# %%
#turning the turtle left
turtle.left(90)

# %% [markdown]
# ![Python%20Turtle%20Graphics%201_20_2024%209_54_24%20PM.png](attachment:Python%20Turtle%20Graphics%201_20_2024%209_54_24%20PM.png)

# %%
#moving the turtle forward and turning again
turtle.foreward(100)
turtle.left(90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 #moving the turtle forward and turning again
# ----> 2 turtle.foreward(100)
#       3 turtle.left(90)
#
# AttributeError: module 'turtle' has no attribute 'foreward'

# %%
#another spelling error
turtle.forward(100)
turtle.left(90)

# %% [markdown]
# ![Python%20Turtle%20Graphics%201_20_2024%209_55_32%20PM.png](attachment:Python%20Turtle%20Graphics%201_20_2024%209_55_32%20PM.png)

# %%
#finishing the square
turtle.forward(100)
turtle.left(90)
turtle.forward(100)

# %% [markdown]
# ![Python%20Turtle%20Graphics%201_20_2024%209_59_46%20PM.png](attachment:Python%20Turtle%20Graphics%201_20_2024%209_59_46%20PM.png)

# %%
#getting ready to draw the circle
turtle.penup()

# %% [markdown]
# At this point I realized this problem is impossible as if there is a circle with a radius of 80, its diameter would be 160 pixels, which does not fit inside the 100x100 square.

# %% [markdown]
# ### problem 14
#
# The textbook asks us to Write the turtle graphics statements to draw a square that is 100 pixels wide on each
# side and filled with the color blue.

# %% [markdown]
# from problem 15, I already have the 100 pixel wide square made. All I need to do now is fill the square with the color blue.

# %%
#hiding the cursur (turtle)
turtle.hideturtle()

# %%
#coloring the circle blue
turtle.fillcolor('blue')
turtle.begin_fill()
turtle.goto(100, 0)
turtle.goto(100,100)
turtle.goto(0,100)
turtle.end_fill()

# %% [markdown]
# ![Python%20Turtle%20Graphics%201_20_2024%2011_30_36%20PM.png](attachment:Python%20Turtle%20Graphics%201_20_2024%2011_30_36%20PM.png)

# %% [markdown]
# Just a note, all these images look vary faint, my turtle graphics was not responding whenever I tried to take a screenshot.

# %% [markdown]
# ## Programming Exercises

# %% [markdown]
# ### Problem 3
#
# the textbook asks us to Write a program that asks the user to enter the total square feet in a tract of land and calculates the number of acres in the tract. One acre of land is equivalent to 43,560 square feet.

# %%
#getting the user to enter the prompt
Square_Feet = input('enter the total square feet in a tract of land')

#performing the calculations
Acres = Square_Feet / 43560

#displaing the output
print('the tract of land is equivalent to {Acres} acres.')
# Out:
# enter the total square feet in a tract of land35
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       2 Square_Feet = input('enter the total square feet in a tract of land')
#       4 #performing the calculations
# ----> 5 Acres = Square_Feet / 43560
#       7 #displaing the output
#       8 print('the tract of land is equivalent to {Acres} acres.')
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
#getting the user to enter the prompt
#I needed to add float in front of input as this is a float
Square_Feet = float(input('enter the total square feet in a tract of land: '))

#performing the calculations
Acres = Square_Feet / 43560

#displaing the output
#I noticed i needed an f string
print(f'the tract of land is equivalent to {Acres} acres.')
# Out:
# enter the total square feet in a tract of land: 87120
# the tract of land is equivalent to 2.0 acres.

# %% [markdown]
# ### Problem 13
#
# the textbook gives us the problem:
#
# A vineyard owner is planting several new rows of grapevines, and needs to know how many grapevines to plant in each row. She has determined that after measuring the length of a future row, she can use the following formula to calculate the number of vines that will fit in the row, along with the trellis end-post assemblies that will need to be constructed at each end of the row:
#
#
# V = (R - 2E) / S
#
# The terms in the formula are:
#
# V is the number of grapevines that will fit in the row.
#
# R is the length of the row, in feet.
#
# E is the amount of space, in feet, used by an end-post assembly.
#
# S is the space between vines, in feet.
#
#
# Write a program that makes the calculation for the vineyard owner. The program should ask the user to input the following:
#
# • The length of the row, in feet
#
# • The amount of space used by an end-post assembly, in feet
#
# • The amount of space between the vines, in feet
#
#
# Once the input data has been entered, the program should calculate and display the number of grapevines that will fit in the row.

# %%
#getting the user to enter the data
R = float(input('enter the length of the row, in feet: '))
E = float(input('enter the amount of space used by an end-post assembly, in feet: '))
S = float(input('enter the amount of space between the vines, in feet" '))

#calculating the amount of grapevines that will fit
V = (R - 2E) / S

#displaying the output
print(f)
